# %% [markdown]
# **Подготовка файла 2700.csv на основе данных сводных файлов 2016-2018 годов**

# %% [markdown]
# - Автор: Клинкова Екатерина
# - Telegram: @ekaklinkova

# %% [markdown]
# `..\Data\{год}\` - папка для хранения созданнного 2700.csv для определенного года
# `..\Data\{год}\Original` - папка для хранения оригинального файла xlsx
# `..\Data\Common\` - папка для хранения итогового результата 2700.csv сводный
# Пример:
#
# E:/IrkutskProject/Data/2016/Original/ф33 правл за 2016г Иркутская обл.xlsx
# E:/IrkutskProject/Data/2016/2700.csv

# %%
# Загрузка библиотек
import pandas as pd
import numpy as np

# %%
# Установка библиотеки для чтения excel. 
# !pip install openpyxl
# !pip install xlrd

# %% [markdown]
# 1) Подкотовка датасетов формы 2700 за 2016-2018 года

# %%
# Список годов для обработки
years = [2016, 2017, 2018]

# Название оригинального файла
#original_names = {
#    2016: 'ф33  правл за 2016г Иркутская обл.xlsx',
#    2017: 'ф.33 и ф.8 Иркутская область 2017г..xls',
#    2018: 'ф.33 и ф.8  Иркутская область  2018.xls'
#}

years = [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# Название оригинального файла
original_names = {
    2016: 'ф33  правл за 2016г Иркутская обл.xlsx',
    2017: 'ф.33 и ф.8 Иркутская область 2017г..xls',
    2018: 'ф.33 и ф.8  Иркутская область  2018.xls',
    2019: 'Свод ф.33 ,ф.8 область правильный 03.02. 2019.xls',
    2020: 'Свод ф.33,8  Иркутская область 2020 верный.xls',
    2021: 'свод область 2021  верный .xls',
    2022: 'свод верн Иркутская область 2022г  ф.33, 8.xls',
    2023: 'свод  Иркутская область верн 2023г..xls',
    2024: 'свод область 2024г.ф.33,8 верн Иркутская обл.xls'
}
original_url = {}
path = 'E:/IrkutskProject/Data/'

df_2700 = {}

for year in years:
    original_path = f'{path}{year}/Original/'
    original_url[year] = original_path + original_names[year]
    
    if year == 2016:
        df = pd.read_excel(original_url[year], engine='openpyxl', sheet_name = '2700-2710')

        # Отфильтруем таблицу 2700
        df_2700[year] = df.iloc[2:21]
    else:
        df = pd.read_excel(original_url[year], engine='xlrd', sheet_name='2600-2800')
        df_2700[year] = df.iloc[20:35]
    
    df_2700[year] = df_2700[year].dropna(how='all', axis=1)
    df_2700[year] = df_2700[year].dropna(how='all')
    df_2700[year] = df_2700[year].drop(df_2700[year].columns[1:2], axis=1)
    df_2700[year].drop(df_2700[year].index[2:3], inplace=True)
    df_2700[year] = df_2700[year].iloc[:, :9]
    df_2700[year] = df_2700[year].reset_index(drop=True)

    df_2700[year].columns = [0, 1, 2, 3, 4, 5, 6, 7, 8]

    df_2700[year].iloc[2, 0] = 'Взято на учет в предыдущем году'
    df_2700[year].iloc[3, 0] = 'Выбыло в другие территории'
    df_2700[year].iloc[4, 0] = 'Умерло от туберкулеза'
    df_2700[year].iloc[5, 0] = 'Умерло от других причин'
    df_2700[year].iloc[6, 0] = 'Диагноз туберкулеза снят'
    df_2700[year].iloc[7, 0] = 'Выделение МБТ прекратилось'
    df_2700[year].iloc[8, 0] = 'Полость распада закрылась'
    df_2700[year].iloc[9, 0] = 'Переведено в III группу'
    df_2700[year].iloc[10, 0] = 'Прибыло из других территорий'
    df_2700[year].iloc[11, 0] = 'Выделение МБТ прекратилось 2'
    df_2700[year].iloc[12, 0] = 'Полость распада закрылась 2'
    df_2700[year].iloc[13, 0] = 'Переведено в III группу 2'

    df_2700[year].iloc[0, 1] = 'Впервые выявленные больные'
    df_2700[year].iloc[1, 1] = 'всего'
    df_2700[year].iloc[1, 2] = 'в том числе бактериовыделители'
    df_2700[year].iloc[1, 3] = 'в том числе с деструкцией легочной ткани'
    df_2700[year].iloc[1, 4] = 'без бактериовыделения и деструкции'
    df_2700[year].iloc[0, 5] = 'Больные с рецидивом туберкулеза'
    df_2700[year].iloc[1, 5] = 'всего'
    df_2700[year].iloc[1, 6] = 'в том числе бактериовыделители'
    df_2700[year].iloc[1, 7] = 'в том числе с деструкцией легочной ткани'
    df_2700[year].iloc[1, 8] = 'без бактериовыделения и деструкции'

    df_2700[year].to_csv(f'E:/IrkutskProject/Data/{year}/2700.csv')

# %%
df_2700[2016]
# Out:
#                                   0                           1  \
# 0                      Наименование  Впервые выявленные больные
# 1                               NaN                       всего
# 2   Взято на учет в предыдущем году                        2541
# 3        Выбыло в другие территории                         147
# 4             Умерло от туберкулеза                         119
# 5           Умерло от других причин                         302
# 6          Диагноз туберкулеза снят                          30
# 7        Выделение МБТ прекратилось                         NaN
# 8         Полость распада закрылась                         NaN
# 9           Переведено в III группу                         922
# 10     Прибыло из других территорий                         202
# 11     Выделение МБТ прекратилось 2                         NaN
# 12      Полость распада закрылась 2                         NaN
# 13        Переведено в III группу 2                          89
#
#                                  2                                         3  \
# 0                              NaN                                       NaN
# 1   в том числе бактериовыделители  в том числе с деструкцией легочной ткани
# 2                             1143                                      1071
# 3                               53                                        42
# 4                               74                                        80
# 5                              138                                       132
# 6                                2                                        12
# 7                              796                                       NaN
# 8                              NaN                                       645
# 9                              263                                       257
# 10                              91                                        83
# 11                              48                                       NaN
# 12                             NaN                                        38
# 13                              38                                        40
#
#                                      4                                5  \
# 0                                  NaN  Больные с рецидивом туберкулеза
# 1   без бактериовыделения и деструкции                            всего
# 2                                  994                              336
# 3                                   53                               17
# 4                                   13                               22
# 5                                   97                               48
# 6                                   18                                1
# 7                                  NaN                              NaN
# 8                                  NaN                              NaN
# 9                                  424                               77
# 10                                  67                               19
# 11                                 NaN                              NaN
# 12                                 NaN                              NaN
# 13                                  45                               10
#
#                                  6                                         7  \
# 0                              NaN                                       NaN
# 1   в том числе бактериовыделители  в том числе с деструкцией легочной ткани
# 2                              174                                       174
# 3                                8                                         6
# 4                               17                                        12
# 5                               25                                        20
# 6                              NaN                                         1
# 7                               88                                       NaN
# 8                              NaN                                        76
# 9                               22                                        23
# 10                              11                                        10
# 11                              10                                       NaN
# 12                             NaN                                         6
# 13                               8                                         3
#
#                                      8
# 0                                  NaN
# 1   без бактериовыделения и деструкции
# 2                                  106
# 3                                    4
# 4                                    2
# 5                                   12
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                   46
# 10                                   6
# 11                                 NaN
# 12                                 NaN
# 13                                   3

# %%
# df_2700[2017]

# %%
# df_2700[2018]

# %%
columns = [
    'Показатель',
    'Уточнение',
    'Год',
    'Значение'
]

data = []

df_2700_long = pd.DataFrame(columns=columns)

for year in years:
    for row_number in range(2, df_2700[year].shape[0]):
        for col_number in range(1, 5):
            new_row = []
            new_row.append(df_2700[year].iloc[row_number, 0])
            new_row.append(df_2700[year].iloc[0, 1] + ' ' + df_2700[year].iloc[1, col_number])
            new_row.append(year)
            new_row.append(df_2700[year].iloc[row_number, col_number] if pd.notnull(df_2700[year].iloc[row_number, col_number]) else 0) 
            data.append(new_row)

        for col_number in range(5, 9):
            new_row = []
            new_row.append(df_2700[year].iloc[row_number, 0])
            new_row.append(df_2700[year].iloc[0, 5] + ' ' + df_2700[year].iloc[1, col_number])
            new_row.append(year)
            new_row.append(df_2700[year].iloc[row_number, col_number] if pd.notnull(df_2700[year].iloc[row_number, col_number]) else 0) 
            data.append(new_row)

df_2700_long = pd.DataFrame(data, columns=columns)

display(df_2700_long)
# Out:
#                           Показатель  \
# 0    Взято на учет в предыдущем году
# 1    Взято на учет в предыдущем году
# 2    Взято на учет в предыдущем году
# 3    Взято на учет в предыдущем году
# 4    Взято на учет в предыдущем году
# ..                               ...
# 859        Переведено в III группу 2
# 860        Переведено в III группу 2
# 861        Переведено в III группу 2
# 862        Переведено в III группу 2
# 863        Переведено в III группу 2
#
#                                              Уточнение   Год Значение
# 0                     Впервые выявленные больные всего  2016     2541
# 1    Впервые выявленные больные в том числе бактери...  2016     1143
# 2    Впервые выявленные больные в том числе с дестр...  2016     1071
# 3    Впервые выявленные больные без бактериовыделен...  2016      994
# 4                Больные с рецидивом туберкулеза всего  2016      336
# ..                                                 ...   ...      ...
# 859  Впервые выявленные больные без бактериовыделен...  2024        4
# 860              Больные с рецидивом туберкулеза всего  2024        0
# 861  Больные с рецидивом туберкулеза в том числе ба...  2024        0
# 862  Больные с рецидивом туберкулеза в том числе с ...  2024        0
# 863  Больные с рецидивом туберкулеза без бактериовы...  2024        0
#
# [864 rows x 4 columns]

# %%
#df_2700_long.to_csv(f'{path}Common/2700_2016-2018.csv', index=False)
df_2700_long.to_csv(f'{path}Common/2700_2016-2024.csv', index=False)
