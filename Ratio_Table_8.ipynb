# %% [markdown]
# **Рассчет относительных показателей**

# %% [markdown]
# - Автор: Клинкова Екатерина
# - Telegram: @ekaklinkova

# %%
# Загрузка библиотек
import pandas as pd
import numpy as np

# %%
path = 'E:/IrkutskProject/Data/'

# df_1100 = pd.read_csv(f'{path}Common_2016-2018/1100_2016-2018.csv')
df_1100 = pd.read_csv(f'{path}Common/1100_2016-2024.csv')
# df_population = pd.read_csv(f'{path}Common_2016-2018/avg_population_2016-2018.csv')
df_population = pd.read_csv(f'{path}Common/avg_population_2016-2024.csv')

# %%
df_1100
# Out:
#                      Показатель  \
# 0                     фтизиатры
# 1                     фтизиатры
# 2                     фтизиатры
# 3   из них фтизиатры участковые
# 4   из них фтизиатры участковые
# 5   из них фтизиатры участковые
# 6                     фтизиатры
# 7                     фтизиатры
# 8                     фтизиатры
# 9   из них фтизиатры участковые
# 10  из них фтизиатры участковые
# 11  из них фтизиатры участковые
# 12                    фтизиатры
# 13                    фтизиатры
# 14                    фтизиатры
# 15  из них фтизиатры участковые
# 16  из них фтизиатры участковые
# 17  из них фтизиатры участковые
# 18                    фтизиатры
# 19                    фтизиатры
# 20                    фтизиатры
# 21  из них фтизиатры участковые
# 22  из них фтизиатры участковые
# 23  из них фтизиатры участковые
# 24                    фтизиатры
# 25                    фтизиатры
# 26                    фтизиатры
# 27  из них фтизиатры участковые
# ...

# %%
df_population
# Out:
#      Год      Пол    Всего     0-4    5-6    7-14  15-17   18-24   25-34  \
# 0   2016    всего  2410851  183794  69207  235186  74979  190183  409323
# 1   2016  мужчины  1114619   94369  35325  120584  38644   94937  206341
# 2   2016  женщины  1296232   89425  33883  114603  36336   95247  202982
# 3   2017    всего  2406548  180095  71944  242241  76615  179732  400958
# 4   2017  мужчины  1112389   92675  36680  124173  39412   89836  202508
# 5   2017  женщины  1294159   87420  35265  118068  37204   89896  198450
# 6   2018    всего  2400979  173758  74222  249204  79314  173837  387116
# 7   2018  мужчины  1109440   89448  37978  127607  40624   87221  195507
# 8   2018  женщины  1291539   84310  36245  121597  38691   86617  191609
# 9   2019    всего  2394478  166162  73833  257439  81632  171343  372520
# 10  2019  мужчины  1106966   85593  37950  131713  41786   86326  188429
# 11  2019  женщины  1287513   80570  35883  125727  39847   85017  184092
# ...

# %%
years = [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

columns = [
    'id',
    'name',
    'short_name',
    'year',
    'indicator',
    'numerator',
    'denominator'
]

data = []
data_2016_2018 = []

df_table_8 = pd.DataFrame(columns=columns)
df_table_8_2016_2018 = pd.DataFrame(columns=columns)


for year in years:
    new_row = []
    new_row.append('id_8.1')
    new_row.append('Обеспеченность населения фтизиатрами (на 10 000 населения)')
    new_row.append('Врачи туб')
    new_row.append(year)
    
    if (year == 2016) or (year == 2017) or (year == 2019) or (year == 2021):
        print('if = ', year)
        # форма 30, табл.1100,   стр.111,   гр.3) /    Среднегодовая численность населения Иркутской области  * 10000
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 110) & (df_1100['Графа'] == 3)]['Значение'].iloc[0]
        denominator = df_population[(df_population['Год'] == year) & (df_population['Пол'] == 'всего')]['Всего'].iloc[0]
    else:
        print('else = ', year)
        # форма 30, табл.1100,   стр.111,   гр.3) /    Среднегодовая численность населения Иркутской области  * 10000
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 3)]['Значение'].iloc[0]
        denominator = df_population[(df_population['Год'] == year) & (df_population['Пол'] == 'всего')]['Всего'].iloc[0]

    if denominator != 0:
        indicator = round(numerator*10000/denominator, 2)
    else:
        indicator = 0.00

    new_row.append(indicator)
    new_row.append(numerator)
    new_row.append(denominator)

    data.append(new_row)
    if year <= 2018:
        data_2016_2018.append(new_row)
    #----
    new_row = []
    new_row.append('id_8.2')
    new_row.append('Укомплектованность кадрами (%)')
    new_row.append('УК врачи туб')
    new_row.append(year)
    
    if (year == 2016) or (year == 2017) or (year == 2019) or (year == 2021):
        # форма 30, табл.1100,   стр.111,   гр.4) /     форма 30, табл.1100,   стр.111,   гр.3) * 100%
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 110) & (df_1100['Графа'] == 4)]['Значение'].iloc[0]
        denominator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 110) & (df_1100['Графа'] == 3)]['Значение'].iloc[0]
    else:
        # форма 30, табл.1100,   стр.111,   гр.4) /     форма 30, табл.1100,   стр.111,   гр.3) * 100%
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 4)]['Значение'].iloc[0]
        denominator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 3)]['Значение'].iloc[0]

    if denominator != 0:
        indicator = round(numerator*100/denominator, 2)
    else:
        indicator = 0.00

    new_row.append(indicator)
    new_row.append(numerator)
    new_row.append(denominator)

    data.append(new_row)
    if year <= 2018:
        data_2016_2018.append(new_row)
    #----
    new_row = []
    new_row.append('id_8.3')
    new_row.append('Укомплектованность физическими лицами (%)')
    new_row.append('УФ врачи туб')
    new_row.append(year)

    if (year == 2016) or (year == 2017) or (year == 2019) or (year == 2021):    
        # форма 30, табл.1100,   стр.111,   гр.9) /     форма 30, табл.1100,   стр.111,   гр.3) * 100%
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 110) & (df_1100['Графа'] == 9)]['Значение'].iloc[0]
        denominator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 110) & (df_1100['Графа'] == 3)]['Значение'].iloc[0]
    else:
        # форма 30, табл.1100,   стр.111,   гр.9) /     форма 30, табл.1100,   стр.111,   гр.3) * 100%
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 9)]['Значение'].iloc[0]
        denominator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 3)]['Значение'].iloc[0]        

    if denominator != 0:
        indicator = round(numerator*100/denominator, 2)
    else:
        indicator = 0.00

    new_row.append(indicator)
    new_row.append(numerator)
    new_row.append(denominator)

    data.append(new_row)
    if year <= 2018:
        data_2016_2018.append(new_row)
    #----
    new_row = []
    new_row.append('id_8.4')
    new_row.append('Коэффициент совместительства')
    new_row.append('КС врачи туб')
    new_row.append(year)

    if (year == 2016) or (year == 2017) or (year == 2019) or (year == 2021):      
        # форма 30, табл.1100,   стр.111,   гр.4) /     форма 30, табл.1100,   стр.111,   гр.9)
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 110) & (df_1100['Графа'] == 4)]['Значение'].iloc[0]
        denominator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 110) & (df_1100['Графа'] == 9)]['Значение'].iloc[0]
    else:
        # форма 30, табл.1100,   стр.111,   гр.4) /     форма 30, табл.1100,   стр.111,   гр.9)
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 4)]['Значение'].iloc[0]
        denominator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 9)]['Значение'].iloc[0]

    if denominator != 0:
        indicator = round(numerator/denominator, 2)
    else:
        indicator = 0.00

    new_row.append(indicator)
    new_row.append(numerator)
    new_row.append(denominator)

    data.append(new_row)
    if year <= 2018:
        data_2016_2018.append(new_row)
    #----
    new_row = []
    new_row.append('id_8.5')
    new_row.append('Обеспеченность населения фтизиатрами участковыми (на 10 000 населения)')
    new_row.append('Врачи туб участ')
    new_row.append(year)

    if (year == 2016) or (year == 2017) or (year == 2019) or (year == 2021):    
        # форма 30, табл.1100,   стр.112,   гр.3) /    Среднегодовая численность населения Иркутской области  * 10000
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 3)]['Значение'].iloc[0]
        denominator = df_population[(df_population['Год'] == year) & (df_population['Пол'] == 'всего')]['Всего'].iloc[0]
    else:
        # форма 30, табл.1100,   стр.112,   гр.3) /    Среднегодовая численность населения Иркутской области  * 10000
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 112) & (df_1100['Графа'] == 3)]['Значение'].iloc[0]
        denominator = df_population[(df_population['Год'] == year) & (df_population['Пол'] == 'всего')]['Всего'].iloc[0]
    
    if denominator != 0:
        indicator = round(numerator*10000/denominator, 2)
    else:
        indicator = 0.00

    new_row.append(indicator)
    new_row.append(numerator)
    new_row.append(denominator)

    data.append(new_row)
    if year <= 2018:
        data_2016_2018.append(new_row)
    #----
    new_row = []
    new_row.append('id_8.6')
    new_row.append('Укомплектованность кадрами  фтизиатрами участковыми (%)')
    new_row.append('УК врачи туб участ')
    new_row.append(year)

    if (year == 2016) or (year == 2017) or (year == 2019) or (year == 2021):     
        # форма 30, табл.1100,   стр.112,   гр.4) /     форма 30, табл.1100,   стр.112,   гр.3) * 100%
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 4)]['Значение'].iloc[0]
        denominator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 3)]['Значение'].iloc[0]
    else:
        # форма 30, табл.1100,   стр.112,   гр.4) /     форма 30, табл.1100,   стр.112,   гр.3) * 100%
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 112) & (df_1100['Графа'] == 4)]['Значение'].iloc[0]
        denominator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 112) & (df_1100['Графа'] == 3)]['Значение'].iloc[0]


    if denominator != 0:
        indicator = round(numerator*100/denominator, 2)
    else:
        indicator = 0.00

    new_row.append(indicator)
    new_row.append(numerator)
    new_row.append(denominator)

    data.append(new_row)
    if year <= 2018:
        data_2016_2018.append(new_row)
    #----
    new_row = []
    new_row.append('id_8.7')
    new_row.append('Укомплектованность  фтизиатрами участковыми физическими лицами (%)')
    new_row.append('УФ врачи туб участ')
    new_row.append(year)

    if (year == 2016) or (year == 2017) or (year == 2019) or (year == 2021):
        # форма 30, табл.1100,   стр.112,   гр.9) /     форма 30, табл.1100,   стр.112,   гр.3) * 100%
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 9)]['Значение'].iloc[0]
        denominator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 3)]['Значение'].iloc[0]
    else:
        # форма 30, табл.1100,   стр.112,   гр.9) /     форма 30, табл.1100,   стр.112,   гр.3) * 100%
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 112) & (df_1100['Графа'] == 9)]['Значение'].iloc[0]
        denominator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 112) & (df_1100['Графа'] == 3)]['Значение'].iloc[0]

    if denominator != 0:
        indicator = round(numerator*100/denominator, 2)
    else:
        indicator = 0.00

    new_row.append(indicator)
    new_row.append(numerator)
    new_row.append(denominator)

    data.append(new_row)
    if year <= 2018:
        data_2016_2018.append(new_row)    
    #----
    new_row = []
    new_row.append('id_8.8')
    new_row.append('Коэффициент совместительства  фтизиатрами участковыми')
    new_row.append('КС врачи туб участ')
    new_row.append(year)
    
    if (year == 2016) or (year == 2017) or (year == 2019) or (year == 2021):
        # форма 30, табл.1100,   стр.112,   гр.4) /     форма 30, табл.1100,   стр.112,   гр.9)
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 4)]['Значение'].iloc[0]
        denominator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 111) & (df_1100['Графа'] == 9)]['Значение'].iloc[0]
    else:
        # форма 30, табл.1100,   стр.112,   гр.4) /     форма 30, табл.1100,   стр.112,   гр.9)
        numerator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 112) & (df_1100['Графа'] == 4)]['Значение'].iloc[0]
        denominator = df_1100[(df_1100['Год'] == year) & (df_1100['Строка'] == 112) & (df_1100['Графа'] == 9)]['Значение'].iloc[0]

    if denominator != 0:
        indicator = round(numerator/denominator, 2)
    else:
        indicator = 0.00

    new_row.append(indicator)
    new_row.append(numerator)
    new_row.append(denominator)

    data.append(new_row)
    if year <= 2018:
        data_2016_2018.append(new_row)
    
    
df_table_8 = pd.DataFrame(data, columns=columns)
df_table_8_2016_2018 = pd.DataFrame(data_2016_2018, columns=columns)
# Out:
# if =  2016
# if =  2017
# else =  2018
# if =  2019
# else =  2020
# if =  2021
# else =  2022
# else =  2023
# else =  2024

# %%
df_table_8.head(30)
# Out:
#         id                                               name  \
# 0   id_8.1  Обеспеченность населения фтизиатрами (на 10 00...
# 1   id_8.2                     Укомплектованность кадрами (%)
# 2   id_8.3          Укомплектованность физическими лицами (%)
# 3   id_8.4                       Коэффициент совместительства
# 4   id_8.5  Обеспеченность населения фтизиатрами участковы...
# 5   id_8.6  Укомплектованность кадрами  фтизиатрами участк...
# 6   id_8.7  Укомплектованность  фтизиатрами участковыми фи...
# 7   id_8.8  Коэффициент совместительства  фтизиатрами учас...
# 8   id_8.1  Обеспеченность населения фтизиатрами (на 10 00...
# 9   id_8.2                     Укомплектованность кадрами (%)
# 10  id_8.3          Укомплектованность физическими лицами (%)
# 11  id_8.4                       Коэффициент совместительства
# 12  id_8.5  Обеспеченность населения фтизиатрами участковы...
# 13  id_8.6  Укомплектованность кадрами  фтизиатрами участк...
# ...

# %%
df_table_8_2016_2018.to_csv(f'{path}Common_2016-2018/table_8_2016-2018.csv', index=False)
df_table_8.to_csv(f'{path}Common/table_8_2016-2024.csv', index=False)
